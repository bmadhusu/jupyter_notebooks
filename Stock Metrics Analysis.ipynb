# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import datetime as datetime
import matplotlib.dates as mdates
import edgar_utils as eu

# %%
# %load_ext autoreload
# %autoreload 2

# %%
jj = eu.get_json_financials_from_tikr('AAPL')

# %%
aapl = eu.BalanceSheet(jj,2014)

# %%
aapl.df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13 entries, 1216 to 7093
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   end     13 non-null     datetime64[ns]
#  1   val     13 non-null     float64
#  2   accn    13 non-null     object
#  3   fy      13 non-null     int64
#  4   fp      13 non-null     object
#  5   form    13 non-null     object
#  6   filed   13 non-null     datetime64[ns]
#  7   frame   0 non-null      object
#  8   tag     13 non-null     object
#  9   units   13 non-null     object
#  10  start   0 non-null      object
# dtypes: datetime64[ns](2), float64(1), int64(1), object(7)
# memory usage: 1.2+ KB

# %%
aapl.df
# Out:
#              end           val                  accn    fy  fp  form  \
# 1098  2014-09-27  2.318390e+11  0001193125-14-383437  2014  FY  10-K
# 1107  2015-09-26  2.904790e+11  0001193125-15-356351  2015  FY  10-K
# 1115  2016-09-24  3.216860e+11  0001628280-16-020309  2016  FY  10-K
# 1123  2017-09-30  3.753190e+11  0000320193-17-000070  2017  FY  10-K
# 1131  2018-09-29  3.657250e+11  0000320193-18-000145  2018  FY  10-K
# 1139  2019-09-28  3.385160e+11  0000320193-19-000119  2019  FY  10-K
# 1147  2020-09-26  3.238880e+11  0000320193-20-000096  2020  FY  10-K
# 1155  2021-09-25  3.510020e+11  0000320193-21-000105  2021  FY  10-K
# 1163  2022-09-24  3.527550e+11  0000320193-22-000108  2022  FY  10-K
# 1216  2014-09-27  6.853100e+10  0001193125-14-383437  2014  FY  10-K
# 1225  2015-09-26  8.937800e+10  0001193125-15-356351  2015  FY  10-K
# 1233  2016-09-24  1.068690e+11  0001628280-16-020309  2016  FY  10-K
# 1241  2017-09-30  1.286450e+11  0000320193-17-000070  2017  FY  10-K
# ...

# %%
kk = pd.pivot(aapl.df, index=['fy'], columns='tag',values='val')

# %%
kk['diff'] = kk.Assets - kk.
# Out:
# tag         Assets  AssetsCurrent      Goodwill   Liabilities  \
# fy
# 2014  2.318390e+11   6.853100e+10  4.616000e+09  1.202920e+11
# 2015  2.904790e+11   8.937800e+10  5.116000e+09  1.711240e+11
# 2016  3.216860e+11   1.068690e+11  5.414000e+09  1.934370e+11
# 2017  3.753190e+11   1.286450e+11  5.717000e+09  2.412720e+11
# 2018  3.657250e+11   1.313390e+11           NaN  2.585780e+11
# 2019  3.385160e+11   1.628190e+11           NaN  2.480280e+11
# 2020  3.238880e+11   1.437130e+11           NaN  2.585490e+11
# 2021  3.510020e+11   1.348360e+11           NaN  2.879120e+11
# 2022  3.527550e+11   1.354050e+11           NaN  3.020830e+11
#
# tag   LiabilitiesAndStockholdersEquity  LiabilitiesCurrent
# fy
# 2014                      2.318390e+11        6.344800e+10
# 2015                      2.904790e+11        8.061000e+10
# 2016                      3.216860e+11        7.900600e+10
# 2017                      3.753190e+11        1.008140e+11
# ...

# %%
aapl.df.groupby(['fy']).sum('val')
# Out:
#                val
# fy
# 2014  7.205650e+11
# 2015  9.271860e+11
# 2016  1.028098e+12
# 2017  1.227086e+12
# 2018  1.238233e+12
# 2019  1.193597e+12
# 2020  1.155430e+12
# 2021  1.250233e+12
# 2022  1.296980e+12

# %%
kk.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8483 entries, 2 to 21305
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   end     8483 non-null   object
#  1   val     8483 non-null   float64
#  2   accn    8483 non-null   object
#  3   fy      8483 non-null   int64
#  4   fp      8483 non-null   object
#  5   form    8483 non-null   object
#  6   filed   8483 non-null   object
#  7   frame   3498 non-null   object
#  8   tag     8483 non-null   object
#  9   units   8483 non-null   object
#  10  start   5669 non-null   object
# dtypes: float64(1), int64(1), object(9)
# memory usage: 795.3+ KB

# %%
kk[(kk.tag.isin(attribs)) & (kk.fy > 2009)]
# Out:
#              end           val                  accn    fy  fp  form  \
# 1177  2009-09-26  3.155500e+10  0001193125-10-238044  2010  FY  10-K
# 1181  2010-09-25  4.167800e+10  0001193125-10-238044  2010  FY  10-K
# 1185  2010-09-25  4.167800e+10  0001193125-11-282113  2011  FY  10-K
# 1189  2011-09-24  4.498800e+10  0001193125-11-282113  2011  FY  10-K
# 1193  2011-09-24  4.498800e+10  0001193125-12-444068  2012  FY  10-K
# 1194  2011-09-24  4.498800e+10  0001193125-13-170623  2012  FY   8-K
# 1198  2012-09-29  5.765300e+10  0001193125-12-444068  2012  FY  10-K
# 1201  2012-09-29  5.765300e+10  0001193125-13-170623  2012  FY   8-K
# 1203  2012-09-29  5.765300e+10  0001193125-13-416534  2013  FY  10-K
# 1207  2013-09-28  7.328600e+10  0001193125-13-416534  2013  FY  10-K
# 1211  2013-09-28  7.328600e+10  0001193125-14-383437  2014  FY  10-K
# 1212  2013-09-28  7.328600e+10  0001193125-15-023732  2014  FY   8-K
# 1216  2014-09-27  6.853100e+10  0001193125-14-383437  2014  FY  10-K
# ...
